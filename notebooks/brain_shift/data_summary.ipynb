# %% [markdown]
# # Brain Shift - Data Summarization
# Tyler Spears, Dr. Tom Fletcher
#
# Part of the Pain in the Net (PITN) project

# %%
# imports
import pathlib
from pathlib import Path
import json
import collections

import numpy as np
import pandas as pd
import csv
import natsort
from pprint import pprint
import nibabel

# visualization libraries
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

plt.rcParams.update({'figure.autolayout': True})
plt.rcParams.update({'figure.facecolor': [1.0, 1.0, 1.0, 1.0]})

# %%
# Data setup

data_dir = Path("/media/tyler/data/pitn/brain_shift")
assert data_dir.exists()
pre_dir = data_dir / "pre"
intra_dir = data_dir / "during"
assert pre_dir.exists() and intra_dir.exists()

# %% [markdown]
# ## Extract image names

# %%
# Pre-Op
pre_img_names = set(img_file.name.replace('.nii.gz', '') for img_file in pre_dir.glob('*.nii.gz'))
pprint(natsort.natsorted(pre_img_names))
pre_json_names = set(json_file.name.replace('.json', '') for json_file in pre_dir.glob("*.json"))
# pprint(natsort.natsorted(pre_json_names))
# All .nii.gz images have an associated .json.
pprint(pre_img_names - pre_json_names)

# Filter out some sequences.
pre_names = set(
    filter(
        lambda s: 'localizer' not in s.casefold() and 'scout' not in s.casefold(), 
        pre_img_names.intersection(pre_json_names)
    )
)
# Out:
# ['SE000001_AAHead_Scout_20200520115951_1',
#  'SE000001_AAHead_Scout_20200520115951_1a',
#  'SE000001_AAHead_Scout_20200520115951_1b',
#  'SE000002_AAHead_Scout_20200520115951_2_i00001',
#  'SE000002_AAHead_Scout_20200520115951_2_i00002',
#  'SE000002_AAHead_Scout_20200520115951_2_i00003',
#  'SE000002_AAHead_Scout_20200520115951_2_i00004',
#  'SE000003_AAHead_Scout_20200520115951_3_i00001',
#  'SE000003_AAHead_Scout_20200520115951_3_i00002',
#  'SE000003_AAHead_Scout_20200520115951_3_i00003',
#  'SE000004_AAHead_Scout_20200520115951_4_i00001',
#  'SE000004_AAHead_Scout_20200520115951_4_i00002',
#  'SE000004_AAHead_Scout_20200520115951_4_i00003',
#  'SE000005_t1_mprage_sag_p2_iso_20200520115951_5',
#  'SE000006_t1_mprage_sag_p2_iso_MPR_Cor_20200520115951_6',
#  'SE000007_t1_mprage_sag_p2_iso_MPR_Tra_20200520115951_7',
#  'SE000008_Ax_diffusion_20200520115951_8',
#  'SE000009_Ax_diffusion_20200520115951_9',
#  'SE000010_t2_spc_flair_sag_p2_iso_20200520115951_10',
#  'SE000011_t2_spc_flair_sag_p2_iso_MPR_Cor_20200520115951_11',
#  'SE000012_t2_spc_flair_sag_p2_iso_MPR_Tra_20200520115951_12',
#  'SE000013_t2_tse_cor_oblique_hippo_20200520115951_13',
#  'SE000014_t2_tirm_cor_dark-fluid_20200520115951_14',
#  'SE000015_t2_tse_tra_320_p2_20200520115951_15',
#  'SE000016_ax-SWI_20200520115951_16',
#  'SE000017_ax-SWI_20200520115951_17_ph',
#  'SE000018_ax-SWI_20200520115951_18',
#  'SE000019_ax-SWI_20200520115951_19',
#  'SE000020_t1_mprage_sag_iso_post_20200520115951_20',
#  'SE000021_t1_mprage_sag_iso_post_MPR_Cor_20200520115951_21',
#  'SE000022_t1_mprage_sag_iso_post_MPR_Tra_20200520115951_22',
#  'SE000023_ax_t1_flash_post_20200520115951_23',
#  'SE000024_t2_tse_tra_320_p2_20200520115951_24']
# set()

# %%
# Intra-Op
intra_img_names = set(img_file.name.replace('.nii.gz', '') for img_file in intra_dir.glob('*.nii.gz'))
pprint(natsort.natsorted(intra_img_names))
intra_json_names = set(json_file.name.replace('.json', '') for json_file in intra_dir.glob("*.json"))
# pprint(natsort.natsorted(intra_json_names))

# A couple of image files do not have a .json file. Incomplete upload?
pprint(intra_img_names - intra_json_names)
pprint((intra_img_names - intra_json_names).intersection(intra_img_names))

# Filter out some sequences.
intra_names = set(
    filter(
        lambda s: 'localizer' not in s.casefold() and 'scout' not in s.casefold(), 
        intra_img_names.intersection(intra_json_names)
    )
)
# Out:
# ['ST000002_T1_SE_AXIAL_20200610090639_11',
#  'ST000002_T1_SE_SAG_20200610090639_10',
#  'ST000002_localizer_20200610090639_2_i00001',
#  'ST000002_localizer_20200610090639_2_i00002',
#  'ST000002_localizer_20200610090639_2_i00003',
#  'ST000002_localizer_20200610090639_5_i00001',
#  'ST000002_localizer_20200610090639_5_i00002',
#  'ST000002_localizer_20200610090639_5_i00003',
#  'ST000002_t1_fl3d_sag_Fiber_20200610090639_7',
#  'ST000002_t1_fl3d_sag_Fiber_20200610090639_101',
#  'ST000002_t1_fl3d_sag_Fiber_20200610090639_101_ROI1',
#  'ST000002_t1_fl3d_sag_Fiber_20200610090639_102',
#  'ST000002_t1_fl3d_sag_Fiber_20200610090639_102_ROI1',
#  'ST000002_t1_fl3d_sag_Pre_Ablation_20200610090639_4',
#  'ST000002_t2_flair_cor_EC_20200610090639_17',
#  'ST000002_t2_flair_cor_EC_Post_Ablation_20200610090639_24',
#  'ST000002_t2_flair_tra_EC_20200610090639_16']
# {'ST000002_t1_fl3d_sag_Fiber_20200610090639_101_ROI1',
#  'ST000002_t1_fl3d_sag_Fiber_20200610090639_102_ROI1'}
# {'ST000002_t1_fl3d_sag_Fiber_20200610090639_101_ROI1',
#  'ST000002_t1_fl3d_sag_Fiber_20200610090639_102_ROI1'}

# %% [markdown]
# ## Metadata Parsing

# %% [markdown]
# ### Pre-Op

# %%
pre_df: pd.DataFrame
pre_df_unique: pd.DataFrame

# Read json files.
meta_keys = set()
pre_meta = list()
for name in pre_names:
    meta_file = pre_dir / (name + '.json')
    with open(meta_file, 'r') as f:
        meta = json.load(f)
    meta['file_name'] = name
    meta.pop('ImageOrientationPatientDICOM')
    meta.pop('ImageType')
    pre_meta.append(meta)
    if not meta_keys:
        meta_keys = meta_keys.union(meta.keys())
    else:
        meta_keys = meta_keys.intersection(meta.keys())

# Sub-select each metadata according to the fields present in all metadata.
pre_meta = [
    dict(
        filter(
            lambda kv: kv[0] in meta_keys,
            super_meta.items()
        )
    ) for super_meta in pre_meta
]

pre_df = pd.DataFrame.from_dict(pre_meta).set_index('file_name')

# Further sub-select fields that have more than one value throughout the table.
pre_df_unique = pre_df.loc[
    :,
    list(
        len(pre_subj[1].astype(str).unique()) > 1 for pre_subj in pre_df.items()
    )
]

# %%
# Load corresponding images for additional metadata.
nifti_meta = list()

for name in pre_df.index:
    img = nibabel.load(pre_dir / (name + '.nii.gz'))
    header = img.header
    header_d = dict(header)
    spatial_unit = header.get_xyzt_units()[0]
    x_size = header.get_zooms()[0]
    y_size = header.get_zooms()[1]
    z_size = header.get_zooms()[2]
    meta = {
        'file_name': name,
        'shape': str(img.shape),#.replace(',', 'x').replace(' ', ''),
        'description': str(header_d['descrip'].astype('U')),#.replace(';', '|').replace(' ', ''),
        'x_size': str(x_size) + spatial_unit,
        'y_size': str(y_size) + spatial_unit,
        'z_size': str(z_size) + spatial_unit
        }
    
    nifti_meta.append(meta)
    
meta_df = pd.DataFrame.from_dict(nifti_meta).set_index('file_name')

# %%
merge_pre_df = pre_df_unique.merge(meta_df, on='file_name')
merge_pre_df.to_csv('pre_op_meta.csv', quoting=csv.QUOTE_ALL)
merge_pre_df
# Out:
#                                                     ImagingFrequency  \
# file_name
# SE000015_t2_tse_tra_320_p2_20200520115951_15                 123.248
# SE000021_t1_mprage_sag_iso_post_MPR_Cor_2020052...           123.248
# SE000006_t1_mprage_sag_p2_iso_MPR_Cor_202005201...           123.248
# SE000024_t2_tse_tra_320_p2_20200520115951_24                 123.248
# SE000022_t1_mprage_sag_iso_post_MPR_Tra_2020052...           123.248
# SE000007_t1_mprage_sag_p2_iso_MPR_Tra_202005201...           123.248
# SE000013_t2_tse_cor_oblique_hippo_2020052011595...           123.248
# SE000012_t2_spc_flair_sag_p2_iso_MPR_Tra_202005...           123.249
# SE000017_ax-SWI_20200520115951_17_ph                         123.249
# SE000011_t2_spc_flair_sag_p2_iso_MPR_Cor_202005...           123.249
# SE000016_ax-SWI_20200520115951_16                            123.249
# SE000010_t2_spc_flair_sag_p2_iso_20200520115951_10           123.249
# SE000018_ax-SWI_20200520115951_18                            123.249
# SE000019_ax-SWI_20200520115951_19                            123.249
# SE000023_ax_t1_flash_post_20200520115951_23                  123.248
# SE000020_t1_mprage_sag_iso_post_20200520115951_20            123.248
# SE000008_Ax_diffusion_20200520115951_8                       123.249
# SE000014_t2_tirm_cor_dark-fluid_20200520115951_14            123.248
# SE000005_t1_mprage_sag_p2_iso_20200520115951_5               123.248
# SE000009_Ax_diffusion_20200520115951_9                       123.249
#
#                                                    MRAcquisitionType  \
# file_name
# SE000015_t2_tse_tra_320_p2_20200520115951_15                      2D
# SE000021_t1_mprage_sag_iso_post_MPR_Cor_2020052...                3D
# SE000006_t1_mprage_sag_p2_iso_MPR_Cor_202005201...                3D
# SE000024_t2_tse_tra_320_p2_20200520115951_24                      2D
# SE000022_t1_mprage_sag_iso_post_MPR_Tra_2020052...                3D
# SE000007_t1_mprage_sag_p2_iso_MPR_Tra_202005201...                3D
# SE000013_t2_tse_cor_oblique_hippo_2020052011595...                2D
# SE000012_t2_spc_flair_sag_p2_iso_MPR_Tra_202005...                3D
# SE000017_ax-SWI_20200520115951_17_ph                              3D
# SE000011_t2_spc_flair_sag_p2_iso_MPR_Cor_202005...                3D
# SE000016_ax-SWI_20200520115951_16                                 3D
# SE000010_t2_spc_flair_sag_p2_iso_20200520115951_10                3D
# SE000018_ax-SWI_20200520115951_18                                 3D
# SE000019_ax-SWI_20200520115951_19                                 3D
# SE000023_ax_t1_flash_post_20200520115951_23                       2D
# SE000020_t1_mprage_sag_iso_post_20200520115951_20                 3D
# SE000008_Ax_diffusion_20200520115951_8                            2D
# SE000014_t2_tirm_cor_dark-fluid_20200520115951_14                 2D
# SE000005_t1_mprage_sag_p2_iso_20200520115951_5                    3D
# SE000009_Ax_diffusion_20200520115951_9                            2D
#
#                                                                   SeriesDescription  \
# file_name
# SE000015_t2_tse_tra_320_p2_20200520115951_15                      t2_tse_tra_320_p2
# SE000021_t1_mprage_sag_iso_post_MPR_Cor_2020052...   t1_mprage_sag_iso post_MPR_Cor
# SE000006_t1_mprage_sag_p2_iso_MPR_Cor_202005201...     t1_mprage_sag_p2_iso_MPR_Cor
# SE000024_t2_tse_tra_320_p2_20200520115951_24                             KEY_IMAGES
# SE000022_t1_mprage_sag_iso_post_MPR_Tra_2020052...   t1_mprage_sag_iso post_MPR_Tra
# SE000007_t1_mprage_sag_p2_iso_MPR_Tra_202005201...     t1_mprage_sag_p2_iso_MPR_Tra
# SE000013_t2_tse_cor_oblique_hippo_2020052011595...         t2_tse_cor_oblique_hippo
# SE000012_t2_spc_flair_sag_p2_iso_MPR_Tra_202005...  t2_spc_flair_sag_p2_iso_MPR_Tra
# SE000017_ax-SWI_20200520115951_17_ph                                     Pha_Images
# SE000011_t2_spc_flair_sag_p2_iso_MPR_Cor_202005...  t2_spc_flair_sag_p2_iso_MPR_Cor
# SE000016_ax-SWI_20200520115951_16                                        Mag_Images
# SE000010_t2_spc_flair_sag_p2_iso_20200520115951_10          t2_spc_flair_sag_p2_iso
# SE000018_ax-SWI_20200520115951_18                                    mIP_Images(SW)
# SE000019_ax-SWI_20200520115951_19                                        SWI_Images
# SE000023_ax_t1_flash_post_20200520115951_23                        ax t1 flash post
# SE000020_t1_mprage_sag_iso_post_20200520115951_20            t1_mprage_sag_iso post
# SE000008_Ax_diffusion_20200520115951_8                          Ax diffusion_TRACEW
# SE000014_t2_tirm_cor_dark-fluid_20200520115951_14            t2_tirm_cor_dark-fluid
# SE000005_t1_mprage_sag_p2_iso_20200520115951_5                 t1_mprage_sag_p2_iso
# SE000009_Ax_diffusion_20200520115951_9                             Ax diffusion_ADC
#
#                                                                        ProtocolName  \
# file_name
# SE000015_t2_tse_tra_320_p2_20200520115951_15                      t2_tse_tra_320_p2
# SE000021_t1_mprage_sag_iso_post_MPR_Cor_2020052...   t1_mprage_sag_iso post_MPR_Cor
# SE000006_t1_mprage_sag_p2_iso_MPR_Cor_202005201...     t1_mprage_sag_p2_iso_MPR_Cor
# SE000024_t2_tse_tra_320_p2_20200520115951_24                      t2_tse_tra_320_p2
# SE000022_t1_mprage_sag_iso_post_MPR_Tra_2020052...   t1_mprage_sag_iso post_MPR_Tra
# SE000007_t1_mprage_sag_p2_iso_MPR_Tra_202005201...     t1_mprage_sag_p2_iso_MPR_Tra
# SE000013_t2_tse_cor_oblique_hippo_2020052011595...         t2_tse_cor_oblique_hippo
# SE000012_t2_spc_flair_sag_p2_iso_MPR_Tra_202005...  t2_spc_flair_sag_p2_iso_MPR_Tra
# SE000017_ax-SWI_20200520115951_17_ph                                         ax-SWI
# SE000011_t2_spc_flair_sag_p2_iso_MPR_Cor_202005...  t2_spc_flair_sag_p2_iso_MPR_Cor
# SE000016_ax-SWI_20200520115951_16                                            ax-SWI
# SE000010_t2_spc_flair_sag_p2_iso_20200520115951_10          t2_spc_flair_sag_p2_iso
# SE000018_ax-SWI_20200520115951_18                                            ax-SWI
# SE000019_ax-SWI_20200520115951_19                                            ax-SWI
# SE000023_ax_t1_flash_post_20200520115951_23                        ax t1 flash post
# SE000020_t1_mprage_sag_iso_post_20200520115951_20            t1_mprage_sag_iso post
# SE000008_Ax_diffusion_20200520115951_8                                 Ax diffusion
# SE000014_t2_tirm_cor_dark-fluid_20200520115951_14            t2_tirm_cor_dark-fluid
# SE000005_t1_mprage_sag_p2_iso_20200520115951_5                 t1_mprage_sag_p2_iso
# SE000009_Ax_diffusion_20200520115951_9                                 Ax diffusion
#
#                                                    ScanningSequence  \
# file_name
# SE000015_t2_tse_tra_320_p2_20200520115951_15                     SE
# SE000021_t1_mprage_sag_iso_post_MPR_Cor_2020052...            GR\IR
# SE000006_t1_mprage_sag_p2_iso_MPR_Cor_202005201...            GR\IR
# SE000024_t2_tse_tra_320_p2_20200520115951_24                     SE
# SE000022_t1_mprage_sag_iso_post_MPR_Tra_2020052...            GR\IR
# SE000007_t1_mprage_sag_p2_iso_MPR_Tra_202005201...            GR\IR
# SE000013_t2_tse_cor_oblique_hippo_2020052011595...               SE
# SE000012_t2_spc_flair_sag_p2_iso_MPR_Tra_202005...            SE\IR
# SE000017_ax-SWI_20200520115951_17_ph                             GR
# SE000011_t2_spc_flair_sag_p2_iso_MPR_Cor_202005...            SE\IR
# SE000016_ax-SWI_20200520115951_16                                GR
# SE000010_t2_spc_flair_sag_p2_iso_20200520115951_10            SE\IR
# SE000018_ax-SWI_20200520115951_18                                GR
# SE000019_ax-SWI_20200520115951_19                                GR
# SE000023_ax_t1_flash_post_20200520115951_23                      GR
# SE000020_t1_mprage_sag_iso_post_20200520115951_20             GR\IR
# SE000008_Ax_diffusion_20200520115951_8                           EP
# SE000014_t2_tirm_cor_dark-fluid_20200520115951_14             SE\IR
# SE000005_t1_mprage_sag_p2_iso_20200520115951_5                GR\IR
# SE000009_Ax_diffusion_20200520115951_9                           EP
#
#                                                    SequenceVariant  \
# file_name
# SE000015_t2_tse_tra_320_p2_20200520115951_15             SK\SP\OSP
# SE000021_t1_mprage_sag_iso_post_MPR_Cor_2020052...        SK\SP\MP
# SE000006_t1_mprage_sag_p2_iso_MPR_Cor_202005201...        SK\SP\MP
# SE000024_t2_tse_tra_320_p2_20200520115951_24             SK\SP\OSP
# SE000022_t1_mprage_sag_iso_post_MPR_Tra_2020052...        SK\SP\MP
# SE000007_t1_mprage_sag_p2_iso_MPR_Tra_202005201...        SK\SP\MP
# SE000013_t2_tse_cor_oblique_hippo_2020052011595...       SK\SP\OSP
# SE000012_t2_spc_flair_sag_p2_iso_MPR_Tra_202005...        SK\SP\MP
# SE000017_ax-SWI_20200520115951_17_ph                        SP\OSP
# SE000011_t2_spc_flair_sag_p2_iso_MPR_Cor_202005...        SK\SP\MP
# SE000016_ax-SWI_20200520115951_16                           SP\OSP
# SE000010_t2_spc_flair_sag_p2_iso_20200520115951_10        SK\SP\MP
# SE000018_ax-SWI_20200520115951_18                           SP\OSP
# SE000019_ax-SWI_20200520115951_19                           SP\OSP
# SE000023_ax_t1_flash_post_20200520115951_23                     SP
# SE000020_t1_mprage_sag_iso_post_20200520115951_20         SK\SP\MP
# SE000008_Ax_diffusion_20200520115951_8                   SK\SP\OSP
# SE000014_t2_tirm_cor_dark-fluid_20200520115951_14     SK\SP\MP\OSP
# SE000005_t1_mprage_sag_p2_iso_20200520115951_5            SK\SP\MP
# SE000009_Ax_diffusion_20200520115951_9                   SK\SP\OSP
#
#                                                     SequenceName  \
# file_name
# SE000015_t2_tse_tra_320_p2_20200520115951_15          *tse2d1_19
# SE000021_t1_mprage_sag_iso_post_MPR_Cor_2020052...  *tfl3d1_16ns
# SE000006_t1_mprage_sag_p2_iso_MPR_Cor_202005201...  *tfl3d1_16ns
# SE000024_t2_tse_tra_320_p2_20200520115951_24          *tse2d1_19
# SE000022_t1_mprage_sag_iso_post_MPR_Tra_2020052...  *tfl3d1_16ns
# SE000007_t1_mprage_sag_p2_iso_MPR_Tra_202005201...  *tfl3d1_16ns
# SE000013_t2_tse_cor_oblique_hippo_2020052011595...    *tse2d1_18
# SE000012_t2_spc_flair_sag_p2_iso_MPR_Tra_202005...  *spcir_278ns
# SE000017_ax-SWI_20200520115951_17_ph                    *swi3d1r
# SE000011_t2_spc_flair_sag_p2_iso_MPR_Cor_202005...  *spcir_278ns
# SE000016_ax-SWI_20200520115951_16                       *swi3d1r
# SE000010_t2_spc_flair_sag_p2_iso_20200520115951_10  *spcir_278ns
# SE000018_ax-SWI_20200520115951_18                       *swi3d1r
# SE000019_ax-SWI_20200520115951_19                       *swi3d1r
# SE000023_ax_t1_flash_post_20200520115951_23               *fl2d1
# SE000020_t1_mprage_sag_iso_post_20200520115951_20   *tfl3d1_16ns
# SE000008_Ax_diffusion_20200520115951_8                    *ep_b0
# SE000014_t2_tirm_cor_dark-fluid_20200520115951_14     *tir2d1_26
# SE000005_t1_mprage_sag_p2_iso_20200520115951_5      *tfl3d1_16ns
# SE000009_Ax_diffusion_20200520115951_9               *ep_b0_1000
#
#                                                     SeriesNumber  \
# file_name
# SE000015_t2_tse_tra_320_p2_20200520115951_15                  15
# SE000021_t1_mprage_sag_iso_post_MPR_Cor_2020052...            21
# SE000006_t1_mprage_sag_p2_iso_MPR_Cor_202005201...             6
# SE000024_t2_tse_tra_320_p2_20200520115951_24                  24
# SE000022_t1_mprage_sag_iso_post_MPR_Tra_2020052...            22
# SE000007_t1_mprage_sag_p2_iso_MPR_Tra_202005201...             7
# SE000013_t2_tse_cor_oblique_hippo_2020052011595...            13
# SE000012_t2_spc_flair_sag_p2_iso_MPR_Tra_202005...            12
# SE000017_ax-SWI_20200520115951_17_ph                          17
# SE000011_t2_spc_flair_sag_p2_iso_MPR_Cor_202005...            11
# SE000016_ax-SWI_20200520115951_16                             16
# SE000010_t2_spc_flair_sag_p2_iso_20200520115951_10            10
# SE000018_ax-SWI_20200520115951_18                             18
# SE000019_ax-SWI_20200520115951_19                             19
# SE000023_ax_t1_flash_post_20200520115951_23                   23
# SE000020_t1_mprage_sag_iso_post_20200520115951_20             20
# SE000008_Ax_diffusion_20200520115951_8                         8
# SE000014_t2_tirm_cor_dark-fluid_20200520115951_14             14
# SE000005_t1_mprage_sag_p2_iso_20200520115951_5                 5
# SE000009_Ax_diffusion_20200520115951_9                         9
#
#                                                     AcquisitionTime  \
# file_name
# SE000015_t2_tse_tra_320_p2_20200520115951_15        12:31:51.965000
# SE000021_t1_mprage_sag_iso_post_MPR_Cor_2020052...  12:43:14.452500
# SE000006_t1_mprage_sag_p2_iso_MPR_Cor_202005201...  12:07:30.385000
# SE000024_t2_tse_tra_320_p2_20200520115951_24        12:31:47.235000
# SE000022_t1_mprage_sag_iso_post_MPR_Tra_2020052...  12:43:14.452500
# SE000007_t1_mprage_sag_p2_iso_MPR_Tra_202005201...  12:07:30.385000
# SE000013_t2_tse_cor_oblique_hippo_2020052011595...  12:21:33.992500
# SE000012_t2_spc_flair_sag_p2_iso_MPR_Tra_202005...  12:15:14.202500
# SE000017_ax-SWI_20200520115951_17_ph                 12:35:9.132500
# SE000011_t2_spc_flair_sag_p2_iso_MPR_Cor_202005...  12:15:14.202500
# SE000016_ax-SWI_20200520115951_16                    12:35:9.132500
# SE000010_t2_spc_flair_sag_p2_iso_20200520115951_10  12:15:14.202500
# SE000018_ax-SWI_20200520115951_18                    12:35:9.132500
# SE000019_ax-SWI_20200520115951_19                    12:35:9.132500
# SE000023_ax_t1_flash_post_20200520115951_23          12:48:2.320000
# SE000020_t1_mprage_sag_iso_post_20200520115951_20   12:43:14.452500
# SE000008_Ax_diffusion_20200520115951_8               12:14:8.680000
# SE000014_t2_tirm_cor_dark-fluid_20200520115951_14   12:29:10.527500
# SE000005_t1_mprage_sag_p2_iso_20200520115951_5      12:07:30.385000
# SE000009_Ax_diffusion_20200520115951_9              12:14:40.280000
#
#                                                     SliceThickness  ...  \
# file_name                                                           ...
# SE000015_t2_tse_tra_320_p2_20200520115951_15                   3.0  ...
# SE000021_t1_mprage_sag_iso_post_MPR_Cor_2020052...             1.0  ...
# SE000006_t1_mprage_sag_p2_iso_MPR_Cor_202005201...             1.0  ...
# SE000024_t2_tse_tra_320_p2_20200520115951_24                   3.0  ...
# SE000022_t1_mprage_sag_iso_post_MPR_Tra_2020052...             1.0  ...
# SE000007_t1_mprage_sag_p2_iso_MPR_Tra_202005201...             1.0  ...
# SE000013_t2_tse_cor_oblique_hippo_2020052011595...             3.0  ...
# SE000012_t2_spc_flair_sag_p2_iso_MPR_Tra_202005...             1.0  ...
# SE000017_ax-SWI_20200520115951_17_ph                           1.5  ...
# SE000011_t2_spc_flair_sag_p2_iso_MPR_Cor_202005...             1.0  ...
# SE000016_ax-SWI_20200520115951_16                              1.5  ...
# SE000010_t2_spc_flair_sag_p2_iso_20200520115951_10             1.0  ...
# SE000018_ax-SWI_20200520115951_18                             12.0  ...
# SE000019_ax-SWI_20200520115951_19                              1.5  ...
# SE000023_ax_t1_flash_post_20200520115951_23                    5.0  ...
# SE000020_t1_mprage_sag_iso_post_20200520115951_20              1.0  ...
# SE000008_Ax_diffusion_20200520115951_8                         5.0  ...
# SE000014_t2_tirm_cor_dark-fluid_20200520115951_14              3.0  ...
# SE000005_t1_mprage_sag_p2_iso_20200520115951_5                 1.0  ...
# SE000009_Ax_diffusion_20200520115951_9                         5.0  ...
#
#                                                     PercentSampling  \
# file_name
# SE000015_t2_tse_tra_320_p2_20200520115951_15                     75
# SE000021_t1_mprage_sag_iso_post_MPR_Cor_2020052...              100
# SE000006_t1_mprage_sag_p2_iso_MPR_Cor_202005201...              100
# SE000024_t2_tse_tra_320_p2_20200520115951_24                     75
# SE000022_t1_mprage_sag_iso_post_MPR_Tra_2020052...              100
# SE000007_t1_mprage_sag_p2_iso_MPR_Tra_202005201...              100
# SE000013_t2_tse_cor_oblique_hippo_2020052011595...               80
# SE000012_t2_spc_flair_sag_p2_iso_MPR_Tra_202005...              100
# SE000017_ax-SWI_20200520115951_17_ph                             90
# SE000011_t2_spc_flair_sag_p2_iso_MPR_Cor_202005...              100
# SE000016_ax-SWI_20200520115951_16                                90
# SE000010_t2_spc_flair_sag_p2_iso_20200520115951_10              100
# SE000018_ax-SWI_20200520115951_18                                90
# SE000019_ax-SWI_20200520115951_19                                90
# SE000023_ax_t1_flash_post_20200520115951_23                     100
# SE000020_t1_mprage_sag_iso_post_20200520115951_20               100
# SE000008_Ax_diffusion_20200520115951_8                          100
# SE000014_t2_tirm_cor_dark-fluid_20200520115951_14                75
# SE000005_t1_mprage_sag_p2_iso_20200520115951_5                  100
# SE000009_Ax_diffusion_20200520115951_9                          100
#
#                                                     PhaseEncodingSteps  \
# file_name
# SE000015_t2_tse_tra_320_p2_20200520115951_15                       304
# SE000021_t1_mprage_sag_iso_post_MPR_Cor_2020052...                 255
# SE000006_t1_mprage_sag_p2_iso_MPR_Cor_202005201...                 255
# SE000024_t2_tse_tra_320_p2_20200520115951_24                       304
# SE000022_t1_mprage_sag_iso_post_MPR_Tra_2020052...                 255
# SE000007_t1_mprage_sag_p2_iso_MPR_Tra_202005201...                 255
# SE000013_t2_tse_cor_oblique_hippo_2020052011595...                 396
# SE000012_t2_spc_flair_sag_p2_iso_MPR_Tra_202005...                 223
# SE000017_ax-SWI_20200520115951_17_ph                               202
# SE000011_t2_spc_flair_sag_p2_iso_MPR_Cor_202005...                 223
# SE000016_ax-SWI_20200520115951_16                                  202
# SE000010_t2_spc_flair_sag_p2_iso_20200520115951_10                 223
# SE000018_ax-SWI_20200520115951_18                                  202
# SE000019_ax-SWI_20200520115951_19                                  202
# SE000023_ax_t1_flash_post_20200520115951_23                        232
# SE000020_t1_mprage_sag_iso_post_20200520115951_20                  255
# SE000008_Ax_diffusion_20200520115951_8                             146
# SE000014_t2_tirm_cor_dark-fluid_20200520115951_14                  234
# SE000005_t1_mprage_sag_p2_iso_20200520115951_5                     255
# SE000009_Ax_diffusion_20200520115951_9                             146
#
#                                                     AcquisitionMatrixPE  \
# file_name
# SE000015_t2_tse_tra_320_p2_20200520115951_15                        279
# SE000021_t1_mprage_sag_iso_post_MPR_Cor_2020052...                  256
# SE000006_t1_mprage_sag_p2_iso_MPR_Cor_202005201...                  256
# SE000024_t2_tse_tra_320_p2_20200520115951_24                        279
# SE000022_t1_mprage_sag_iso_post_MPR_Tra_2020052...                  256
# SE000007_t1_mprage_sag_p2_iso_MPR_Tra_202005201...                  256
# SE000013_t2_tse_cor_oblique_hippo_2020052011595...                  307
# SE000012_t2_spc_flair_sag_p2_iso_MPR_Tra_202005...                  256
# SE000017_ax-SWI_20200520115951_17_ph                                202
# SE000011_t2_spc_flair_sag_p2_iso_MPR_Cor_202005...                  256
# SE000016_ax-SWI_20200520115951_16                                   202
# SE000010_t2_spc_flair_sag_p2_iso_20200520115951_10                  256
# SE000018_ax-SWI_20200520115951_18                                   202
# SE000019_ax-SWI_20200520115951_19                                   202
# SE000023_ax_t1_flash_post_20200520115951_23                         232
# SE000020_t1_mprage_sag_iso_post_20200520115951_20                   256
# SE000008_Ax_diffusion_20200520115951_8                              170
# SE000014_t2_tirm_cor_dark-fluid_20200520115951_14                   192
# SE000005_t1_mprage_sag_p2_iso_20200520115951_5                      256
# SE000009_Ax_diffusion_20200520115951_9                              170
#
#                                                     ReconMatrixPE  \
# file_name
# SE000015_t2_tse_tra_320_p2_20200520115951_15                  372
# SE000021_t1_mprage_sag_iso_post_MPR_Cor_2020052...            256
# SE000006_t1_mprage_sag_p2_iso_MPR_Cor_202005201...            256
# SE000024_t2_tse_tra_320_p2_20200520115951_24                 1024
# SE000022_t1_mprage_sag_iso_post_MPR_Tra_2020052...            512
# SE000007_t1_mprage_sag_p2_iso_MPR_Tra_202005201...            512
# SE000013_t2_tse_cor_oblique_hippo_2020052011595...            384
# SE000012_t2_spc_flair_sag_p2_iso_MPR_Tra_202005...            524
# SE000017_ax-SWI_20200520115951_17_ph                          224
# SE000011_t2_spc_flair_sag_p2_iso_MPR_Cor_202005...            256
# SE000016_ax-SWI_20200520115951_16                             224
# SE000010_t2_spc_flair_sag_p2_iso_20200520115951_10            512
# SE000018_ax-SWI_20200520115951_18                             224
# SE000019_ax-SWI_20200520115951_19                             224
# SE000023_ax_t1_flash_post_20200520115951_23                   232
# SE000020_t1_mprage_sag_iso_post_20200520115951_20             512
# SE000008_Ax_diffusion_20200520115951_8                        340
# SE000014_t2_tirm_cor_dark-fluid_20200520115951_14             512
# SE000005_t1_mprage_sag_p2_iso_20200520115951_5                512
# SE000009_Ax_diffusion_20200520115951_9                        340
#
#                                                     PixelBandwidth  \
# file_name
# SE000015_t2_tse_tra_320_p2_20200520115951_15                   215
# SE000021_t1_mprage_sag_iso_post_MPR_Cor_2020052...             210
# SE000006_t1_mprage_sag_p2_iso_MPR_Cor_202005201...             220
# SE000024_t2_tse_tra_320_p2_20200520115951_24                   215
# SE000022_t1_mprage_sag_iso_post_MPR_Tra_2020052...             210
# SE000007_t1_mprage_sag_p2_iso_MPR_Tra_202005201...             220
# SE000013_t2_tse_cor_oblique_hippo_2020052011595...             220
# SE000012_t2_spc_flair_sag_p2_iso_MPR_Tra_202005...             750
# SE000017_ax-SWI_20200520115951_17_ph                           120
# SE000011_t2_spc_flair_sag_p2_iso_MPR_Cor_202005...             750
# SE000016_ax-SWI_20200520115951_16                              120
# SE000010_t2_spc_flair_sag_p2_iso_20200520115951_10             750
# SE000018_ax-SWI_20200520115951_18                              120
# SE000019_ax-SWI_20200520115951_19                              120
# SE000023_ax_t1_flash_post_20200520115951_23                    355
# SE000020_t1_mprage_sag_iso_post_20200520115951_20              210
# SE000008_Ax_diffusion_20200520115951_8                        1175
# SE000014_t2_tirm_cor_dark-fluid_20200520115951_14              260
# SE000005_t1_mprage_sag_p2_iso_20200520115951_5                 220
# SE000009_Ax_diffusion_20200520115951_9                        1175
#
#                                                                 shape  \
# file_name
# SE000015_t2_tse_tra_320_p2_20200520115951_15           (372, 384, 51)
# SE000021_t1_mprage_sag_iso_post_MPR_Cor_2020052...    (465, 271, 448)
# SE000006_t1_mprage_sag_p2_iso_MPR_Cor_202005201...    (465, 148, 448)
# SE000024_t2_tse_tra_320_p2_20200520115951_24          (1024, 1024, 1)
# SE000022_t1_mprage_sag_iso_post_MPR_Tra_2020052...    (512, 512, 238)
# SE000007_t1_mprage_sag_p2_iso_MPR_Tra_202005201...    (512, 512, 238)
# SE000013_t2_tse_cor_oblique_hippo_2020052011595...     (384, 384, 41)
# SE000012_t2_spc_flair_sag_p2_iso_MPR_Tra_202005...    (524, 524, 238)
# SE000017_ax-SWI_20200520115951_17_ph                   (224, 256, 96)
# SE000011_t2_spc_flair_sag_p2_iso_MPR_Cor_202005...    (476, 271, 459)
# SE000016_ax-SWI_20200520115951_16                      (224, 256, 96)
# SE000010_t2_spc_flair_sag_p2_iso_20200520115951_10    (176, 512, 512)
# SE000018_ax-SWI_20200520115951_18                      (224, 256, 89)
# SE000019_ax-SWI_20200520115951_19                      (224, 256, 96)
# SE000023_ax_t1_flash_post_20200520115951_23            (232, 256, 33)
# SE000020_t1_mprage_sag_iso_post_20200520115951_20     (192, 512, 512)
# SE000008_Ax_diffusion_20200520115951_8              (340, 340, 33, 2)
# SE000014_t2_tirm_cor_dark-fluid_20200520115951_14      (512, 512, 45)
# SE000005_t1_mprage_sag_p2_iso_20200520115951_5        (192, 512, 512)
# SE000009_Ax_diffusion_20200520115951_9                 (340, 340, 33)
#
#                                                                            description  \
# file_name
# SE000015_t2_tse_tra_320_p2_20200520115951_15             TE=95;Time=123151.965;phase=1
# SE000021_t1_mprage_sag_iso_post_MPR_Cor_2020052...              TE=2.2;Time=124314.452
# SE000006_t1_mprage_sag_p2_iso_MPR_Cor_202005201...              TE=3.2;Time=120730.385
# SE000024_t2_tse_tra_320_p2_20200520115951_24                     TE=95;Time=123147.235
# SE000022_t1_mprage_sag_iso_post_MPR_Tra_2020052...              TE=2.2;Time=124314.452
# SE000007_t1_mprage_sag_p2_iso_MPR_Tra_202005201...              TE=3.2;Time=120730.385
# SE000013_t2_tse_cor_oblique_hippo_2020052011595...    TE=1e+02;Time=122133.992;phase=1
# SE000012_t2_spc_flair_sag_p2_iso_MPR_Tra_202005...          TE=3.8e+02;Time=121514.202
# SE000017_ax-SWI_20200520115951_17_ph                     TE=20;Time=123509.133;phase=1
# SE000011_t2_spc_flair_sag_p2_iso_MPR_Cor_202005...          TE=3.8e+02;Time=121514.202
# SE000016_ax-SWI_20200520115951_16                        TE=20;Time=123509.133;phase=1
# SE000010_t2_spc_flair_sag_p2_iso_20200520115951_10  TE=3.8e+02;Time=121514.202;phase=1
# SE000018_ax-SWI_20200520115951_18                        TE=20;Time=123509.133;phase=1
# SE000019_ax-SWI_20200520115951_19                        TE=20;Time=123509.133;phase=1
# SE000023_ax_t1_flash_post_20200520115951_23             TE=2.3;Time=124802.320;phase=1
# SE000020_t1_mprage_sag_iso_post_20200520115951_20       TE=2.2;Time=124314.452;phase=1
# SE000008_Ax_diffusion_20200520115951_8                   TE=90;Time=121408.680;phase=1
# SE000014_t2_tirm_cor_dark-fluid_20200520115951_14   TE=1.1e+02;Time=122910.527;phase=1
# SE000005_t1_mprage_sag_p2_iso_20200520115951_5          TE=3.2;Time=120730.385;phase=1
# SE000009_Ax_diffusion_20200520115951_9                   TE=90;Time=121440.280;phase=1
#
#                                                           x_size  \
# file_name
# SE000015_t2_tse_tra_320_p2_20200520115951_15         0.5729167mm
# SE000021_t1_mprage_sag_iso_post_MPR_Cor_2020052...         0.5mm
# SE000006_t1_mprage_sag_p2_iso_MPR_Cor_202005201...         0.5mm
# SE000024_t2_tse_tra_320_p2_20200520115951_24        0.33436584mm
# SE000022_t1_mprage_sag_iso_post_MPR_Tra_2020052...         0.5mm
# SE000007_t1_mprage_sag_p2_iso_MPR_Tra_202005201...         0.5mm
# SE000013_t2_tse_cor_oblique_hippo_2020052011595...  0.44270834mm
# SE000012_t2_spc_flair_sag_p2_iso_MPR_Tra_202005...  0.48828125mm
# SE000017_ax-SWI_20200520115951_17_ph                 0.8984375mm
# SE000011_t2_spc_flair_sag_p2_iso_MPR_Cor_202005...  0.48828125mm
# SE000016_ax-SWI_20200520115951_16                    0.8984375mm
# SE000010_t2_spc_flair_sag_p2_iso_20200520115951_10         1.0mm
# SE000018_ax-SWI_20200520115951_18                    0.8984375mm
# SE000019_ax-SWI_20200520115951_19                    0.8984375mm
# SE000023_ax_t1_flash_post_20200520115951_23           0.859375mm
# SE000020_t1_mprage_sag_iso_post_20200520115951_20          1.0mm
# SE000008_Ax_diffusion_20200520115951_8              0.64705884mm
# SE000014_t2_tirm_cor_dark-fluid_20200520115951_14    0.3515625mm
# SE000005_t1_mprage_sag_p2_iso_20200520115951_5             1.0mm
# SE000009_Ax_diffusion_20200520115951_9              0.64705884mm
#
#                                                           y_size        z_size
# file_name
# SE000015_t2_tse_tra_320_p2_20200520115951_15         0.5729167mm         3.0mm
# SE000021_t1_mprage_sag_iso_post_MPR_Cor_2020052...         1.0mm         0.5mm
# SE000006_t1_mprage_sag_p2_iso_MPR_Cor_202005201...         1.0mm         0.5mm
# SE000024_t2_tse_tra_320_p2_20200520115951_24        0.33436584mm         3.0mm
# SE000022_t1_mprage_sag_iso_post_MPR_Tra_2020052...         0.5mm         1.0mm
# SE000007_t1_mprage_sag_p2_iso_MPR_Tra_202005201...         0.5mm         1.0mm
# SE000013_t2_tse_cor_oblique_hippo_2020052011595...  0.44270834mm         3.0mm
# SE000012_t2_spc_flair_sag_p2_iso_MPR_Tra_202005...  0.48828125mm         1.0mm
# SE000017_ax-SWI_20200520115951_17_ph                 0.8984375mm         1.5mm
# SE000011_t2_spc_flair_sag_p2_iso_MPR_Cor_202005...         1.0mm  0.48828125mm
# SE000016_ax-SWI_20200520115951_16                    0.8984375mm         1.5mm
# SE000010_t2_spc_flair_sag_p2_iso_20200520115951_10  0.48828125mm  0.48828125mm
# SE000018_ax-SWI_20200520115951_18                    0.8984375mm   1.4999943mm
# SE000019_ax-SWI_20200520115951_19                    0.8984375mm         1.5mm
# SE000023_ax_t1_flash_post_20200520115951_23           0.859375mm         5.0mm
# SE000020_t1_mprage_sag_iso_post_20200520115951_20          0.5mm         0.5mm
# SE000008_Ax_diffusion_20200520115951_8              0.64705884mm         5.0mm
# SE000014_t2_tirm_cor_dark-fluid_20200520115951_14    0.3515625mm         3.0mm
# SE000005_t1_mprage_sag_p2_iso_20200520115951_5             0.5mm         0.5mm
# SE000009_Ax_diffusion_20200520115951_9              0.64705884mm         5.0mm
#
# [20 rows x 25 columns]

# %% [markdown]
# ### Intra-Op

# %%
intra_df: pd.DataFrame
intra_df_unique: pd.DataFrame

# Read json files.
meta_keys = set()
intra_meta = list()
for name in intra_names:
    meta_file = intra_dir / (name + '.json')
    with open(meta_file, 'r') as f:
        meta = json.load(f)
    meta['file_name'] = name
    meta.pop('ImageOrientationPatientDICOM', None)
    meta.pop('ImageType', None)
    intra_meta.append(meta)
    if not meta_keys:
        meta_keys = meta_keys.union(meta.keys())
    else:
        meta_keys = meta_keys.intersection(meta.keys())

# Sub-select each metadata according to the fields present in all metadata.
intra_meta = [
    dict(
        filter(
            lambda kv: kv[0] in meta_keys,
            super_meta.items()
        )
    ) for super_meta in intra_meta
]

intra_df = pd.DataFrame.from_dict(intra_meta).set_index('file_name')

# Further sub-select fields that have more than one value throughout the table.
intra_df_unique = intra_df.loc[
    :,
    list(
        len(intra_subj[1].astype(str).unique()) > 1 for intra_subj in intra_df.items()
    )
]

# %%
# Load corresponding images for additional metadata.
nifti_meta = list()

for name in intra_df.index:
    img = nibabel.load(intra_dir / (name + '.nii.gz'))
    header = img.header
    header_d = dict(header)
    spatial_unit = header.get_xyzt_units()[0]
    x_size = header.get_zooms()[0]
    y_size = header.get_zooms()[1]
    z_size = header.get_zooms()[2]
    meta = {
        'file_name': name,
        'shape': img.shape,
        'description': str(header_d['descrip'].astype('U')),
        'x size': str(x_size) + spatial_unit,
        'y size': str(y_size) + spatial_unit,
        'z size': str(z_size) + spatial_unit
        }
    
    nifti_meta.append(meta)
    
meta_df = pd.DataFrame.from_dict(nifti_meta).set_index('file_name')

# %%
merge_intra_df = intra_df_unique.merge(meta_df, on='file_name')
merge_intra_df.to_csv('intra_op_meta.csv', quoting=csv.QUOTE_ALL)
merge_intra_df
# Out:
#                                                     ImagingFrequency  \
# file_name
# ST000002_t1_fl3d_sag_Fiber_20200610090639_7                  63.5976
# ST000002_T1_SE_SAG_20200610090639_10                         63.5976
# ST000002_T1_SE_AXIAL_20200610090639_11                       63.5976
# ST000002_t1_fl3d_sag_Fiber_20200610090639_102                63.5976
# ST000002_t1_fl3d_sag_Pre_Ablation_20200610090639_4           63.5977
# ST000002_t2_flair_cor_EC_Post_Ablation_20200610...           63.5976
# ST000002_t2_flair_cor_EC_20200610090639_17                   63.5976
# ST000002_t2_flair_tra_EC_20200610090639_16                   63.5976
# ST000002_t1_fl3d_sag_Fiber_20200610090639_101                63.5976
#
#                                                    MRAcquisitionType  \
# file_name
# ST000002_t1_fl3d_sag_Fiber_20200610090639_7                       3D
# ST000002_T1_SE_SAG_20200610090639_10                              2D
# ST000002_T1_SE_AXIAL_20200610090639_11                            2D
# ST000002_t1_fl3d_sag_Fiber_20200610090639_102                     3D
# ST000002_t1_fl3d_sag_Pre_Ablation_20200610090639_4                3D
# ST000002_t2_flair_cor_EC_Post_Ablation_20200610...                2D
# ST000002_t2_flair_cor_EC_20200610090639_17                        2D
# ST000002_t2_flair_tra_EC_20200610090639_16                        2D
# ST000002_t1_fl3d_sag_Fiber_20200610090639_101                     3D
#
#                                                                 SeriesDescription  \
# file_name
# ST000002_t1_fl3d_sag_Fiber_20200610090639_7                     t1_fl3d_sag_Fiber
# ST000002_T1_SE_SAG_20200610090639_10                                    T1 SE SAG
# ST000002_T1_SE_AXIAL_20200610090639_11                                T1 SE AXIAL
# ST000002_t1_fl3d_sag_Fiber_20200610090639_102           sag mpr 2<MPR Collection>
# ST000002_t1_fl3d_sag_Pre_Ablation_20200610090639_4       t1_fl3d_sag_Pre Ablation
# ST000002_t2_flair_cor_EC_Post_Ablation_20200610...  t2_flair_cor_EC_Post Ablation
# ST000002_t2_flair_cor_EC_20200610090639_17                        t2_flair_cor_EC
# ST000002_t2_flair_tra_EC_20200610090639_16                        t2_flair_tra_EC
# ST000002_t1_fl3d_sag_Fiber_20200610090639_101           axial mpr<MPR Collection>
#
#                                                                      ProtocolName  \
# file_name
# ST000002_t1_fl3d_sag_Fiber_20200610090639_7                     t1_fl3d_sag_Fiber
# ST000002_T1_SE_SAG_20200610090639_10                                    T1 SE SAG
# ST000002_T1_SE_AXIAL_20200610090639_11                                T1 SE AXIAL
# ST000002_t1_fl3d_sag_Fiber_20200610090639_102                   t1_fl3d_sag_Fiber
# ST000002_t1_fl3d_sag_Pre_Ablation_20200610090639_4       t1_fl3d_sag_Pre Ablation
# ST000002_t2_flair_cor_EC_Post_Ablation_20200610...  t2_flair_cor_EC_Post Ablation
# ST000002_t2_flair_cor_EC_20200610090639_17                        t2_flair_cor_EC
# ST000002_t2_flair_tra_EC_20200610090639_16                        t2_flair_tra_EC
# ST000002_t1_fl3d_sag_Fiber_20200610090639_101                   t1_fl3d_sag_Fiber
#
#                                                    ScanningSequence  \
# file_name
# ST000002_t1_fl3d_sag_Fiber_20200610090639_7                      GR
# ST000002_T1_SE_SAG_20200610090639_10                             SE
# ST000002_T1_SE_AXIAL_20200610090639_11                           SE
# ST000002_t1_fl3d_sag_Fiber_20200610090639_102                    GR
# ST000002_t1_fl3d_sag_Pre_Ablation_20200610090639_4               GR
# ST000002_t2_flair_cor_EC_Post_Ablation_20200610...            SE\IR
# ST000002_t2_flair_cor_EC_20200610090639_17                    SE\IR
# ST000002_t2_flair_tra_EC_20200610090639_16                    SE\IR
# ST000002_t1_fl3d_sag_Fiber_20200610090639_101                    GR
#
#                                                    SequenceVariant  \
# file_name
# ST000002_t1_fl3d_sag_Fiber_20200610090639_7                     SP
# ST000002_T1_SE_SAG_20200610090639_10                            SP
# ST000002_T1_SE_AXIAL_20200610090639_11                          SP
# ST000002_t1_fl3d_sag_Fiber_20200610090639_102                   SP
# ST000002_t1_fl3d_sag_Pre_Ablation_20200610090639_4              SP
# ST000002_t2_flair_cor_EC_Post_Ablation_20200610...    SK\SP\MP\OSP
# ST000002_t2_flair_cor_EC_20200610090639_17            SK\SP\MP\OSP
# ST000002_t2_flair_tra_EC_20200610090639_16            SK\SP\MP\OSP
# ST000002_t1_fl3d_sag_Fiber_20200610090639_101                   SP
#
#                                                    SequenceName  SeriesNumber  \
# file_name
# ST000002_t1_fl3d_sag_Fiber_20200610090639_7              *fl3d1             7
# ST000002_T1_SE_SAG_20200610090639_10                     *se2d1            10
# ST000002_T1_SE_AXIAL_20200610090639_11                   *se2d1            11
# ST000002_t1_fl3d_sag_Fiber_20200610090639_102            *fl3d1           102
# ST000002_t1_fl3d_sag_Pre_Ablation_20200610090639_4       *fl3d1             4
# ST000002_t2_flair_cor_EC_Post_Ablation_20200610...   *tir2d1_19            24
# ST000002_t2_flair_cor_EC_20200610090639_17           *tir2d1_19            17
# ST000002_t2_flair_tra_EC_20200610090639_16           *tir2d1_19            16
# ST000002_t1_fl3d_sag_Fiber_20200610090639_101            *fl3d1           101
#
#                                                     AcquisitionTime  \
# file_name
# ST000002_t1_fl3d_sag_Fiber_20200610090639_7         11:42:30.962500
# ST000002_T1_SE_SAG_20200610090639_10                11:57:48.982500
# ST000002_T1_SE_AXIAL_20200610090639_11              12:00:33.422500
# ST000002_t1_fl3d_sag_Fiber_20200610090639_102       11:42:30.962500
# ST000002_t1_fl3d_sag_Pre_Ablation_20200610090639_4  09:09:23.285000
# ST000002_t2_flair_cor_EC_Post_Ablation_20200610...  13:20:41.917500
# ST000002_t2_flair_cor_EC_20200610090639_17          12:51:26.452500
# ST000002_t2_flair_tra_EC_20200610090639_16          12:43:47.925000
# ST000002_t1_fl3d_sag_Fiber_20200610090639_101       11:42:30.962500
#
#                                                     SliceThickness  ...  \
# file_name                                                           ...
# ST000002_t1_fl3d_sag_Fiber_20200610090639_7                      1  ...
# ST000002_T1_SE_SAG_20200610090639_10                             3  ...
# ST000002_T1_SE_AXIAL_20200610090639_11                           3  ...
# ST000002_t1_fl3d_sag_Fiber_20200610090639_102                    1  ...
# ST000002_t1_fl3d_sag_Pre_Ablation_20200610090639_4               1  ...
# ST000002_t2_flair_cor_EC_Post_Ablation_20200610...               2  ...
# ST000002_t2_flair_cor_EC_20200610090639_17                       2  ...
# ST000002_t2_flair_tra_EC_20200610090639_16                       2  ...
# ST000002_t1_fl3d_sag_Fiber_20200610090639_101                    1  ...
#
#                                                     PercentSampling  \
# file_name
# ST000002_t1_fl3d_sag_Fiber_20200610090639_7                     100
# ST000002_T1_SE_SAG_20200610090639_10                            100
# ST000002_T1_SE_AXIAL_20200610090639_11                          100
# ST000002_t1_fl3d_sag_Fiber_20200610090639_102                   100
# ST000002_t1_fl3d_sag_Pre_Ablation_20200610090639_4              100
# ST000002_t2_flair_cor_EC_Post_Ablation_20200610...               75
# ST000002_t2_flair_cor_EC_20200610090639_17                       75
# ST000002_t2_flair_tra_EC_20200610090639_16                       75
# ST000002_t1_fl3d_sag_Fiber_20200610090639_101                   100
#
#                                                     PhaseEncodingSteps  \
# file_name
# ST000002_t1_fl3d_sag_Fiber_20200610090639_7                        256
# ST000002_T1_SE_SAG_20200610090639_10                               256
# ST000002_T1_SE_AXIAL_20200610090639_11                             256
# ST000002_t1_fl3d_sag_Fiber_20200610090639_102                      256
# ST000002_t1_fl3d_sag_Pre_Ablation_20200610090639_4                 256
# ST000002_t2_flair_cor_EC_Post_Ablation_20200610...                 209
# ST000002_t2_flair_cor_EC_20200610090639_17                         209
# ST000002_t2_flair_tra_EC_20200610090639_16                         209
# ST000002_t1_fl3d_sag_Fiber_20200610090639_101                      256
#
#                                                     AcquisitionMatrixPE  \
# file_name
# ST000002_t1_fl3d_sag_Fiber_20200610090639_7                         256
# ST000002_T1_SE_SAG_20200610090639_10                                256
# ST000002_T1_SE_AXIAL_20200610090639_11                              256
# ST000002_t1_fl3d_sag_Fiber_20200610090639_102                       256
# ST000002_t1_fl3d_sag_Pre_Ablation_20200610090639_4                  256
# ST000002_t2_flair_cor_EC_Post_Ablation_20200610...                  192
# ST000002_t2_flair_cor_EC_20200610090639_17                          192
# ST000002_t2_flair_tra_EC_20200610090639_16                          192
# ST000002_t1_fl3d_sag_Fiber_20200610090639_101                       256
#
#                                                     ReconMatrixPE  \
# file_name
# ST000002_t1_fl3d_sag_Fiber_20200610090639_7                   256
# ST000002_T1_SE_SAG_20200610090639_10                          256
# ST000002_T1_SE_AXIAL_20200610090639_11                        256
# ST000002_t1_fl3d_sag_Fiber_20200610090639_102                 484
# ST000002_t1_fl3d_sag_Pre_Ablation_20200610090639_4            256
# ST000002_t2_flair_cor_EC_Post_Ablation_20200610...            256
# ST000002_t2_flair_cor_EC_20200610090639_17                    256
# ST000002_t2_flair_tra_EC_20200610090639_16                    256
# ST000002_t1_fl3d_sag_Fiber_20200610090639_101                 484
#
#                                                     PixelBandwidth  \
# file_name
# ST000002_t1_fl3d_sag_Fiber_20200610090639_7                    160
# ST000002_T1_SE_SAG_20200610090639_10                           129
# ST000002_T1_SE_AXIAL_20200610090639_11                         129
# ST000002_t1_fl3d_sag_Fiber_20200610090639_102                  160
# ST000002_t1_fl3d_sag_Pre_Ablation_20200610090639_4             160
# ST000002_t2_flair_cor_EC_Post_Ablation_20200610...             130
# ST000002_t2_flair_cor_EC_20200610090639_17                     130
# ST000002_t2_flair_tra_EC_20200610090639_16                     130
# ST000002_t1_fl3d_sag_Fiber_20200610090639_101                  160
#
#                                                               shape  \
# file_name
# ST000002_t1_fl3d_sag_Fiber_20200610090639_7         (240, 256, 256)
# ST000002_T1_SE_SAG_20200610090639_10                  (256, 256, 7)
# ST000002_T1_SE_AXIAL_20200610090639_11                (256, 256, 7)
# ST000002_t1_fl3d_sag_Fiber_20200610090639_102         (484, 484, 1)
# ST000002_t1_fl3d_sag_Pre_Ablation_20200610090639_4  (240, 256, 256)
# ST000002_t2_flair_cor_EC_Post_Ablation_20200610...   (256, 256, 54)
# ST000002_t2_flair_cor_EC_20200610090639_17           (256, 256, 54)
# ST000002_t2_flair_tra_EC_20200610090639_16           (256, 256, 54)
# ST000002_t1_fl3d_sag_Fiber_20200610090639_101         (484, 484, 1)
#
#                                                                            description  \
# file_name
# ST000002_t1_fl3d_sag_Fiber_20200610090639_7             TE=5.7;Time=114230.962;phase=1
# ST000002_T1_SE_SAG_20200610090639_10                    TE=9.5;Time=115748.982;phase=1
# ST000002_T1_SE_AXIAL_20200610090639_11                  TE=9.5;Time=120033.423;phase=1
# ST000002_t1_fl3d_sag_Fiber_20200610090639_102                   TE=5.7;Time=114230.962
# ST000002_t1_fl3d_sag_Pre_Ablation_20200610090639_4       TE=5.7;Time=90923.285;phase=1
# ST000002_t2_flair_cor_EC_Post_Ablation_20200610...  TE=1.2e+02;Time=132041.918;phase=1
# ST000002_t2_flair_cor_EC_20200610090639_17          TE=1.2e+02;Time=125126.452;phase=1
# ST000002_t2_flair_tra_EC_20200610090639_16          TE=1.2e+02;Time=124347.925;phase=1
# ST000002_t1_fl3d_sag_Fiber_20200610090639_101                   TE=5.7;Time=114230.962
#
#                                                          x size       y size  \
# file_name
# ST000002_t1_fl3d_sag_Fiber_20200610090639_7               1.0mm   1.015625mm
# ST000002_T1_SE_SAG_20200610090639_10                 1.015625mm   1.015625mm
# ST000002_T1_SE_AXIAL_20200610090639_11               1.015625mm   1.015625mm
# ST000002_t1_fl3d_sag_Fiber_20200610090639_102       0.5371901mm  0.5371901mm
# ST000002_t1_fl3d_sag_Pre_Ablation_20200610090639_4        1.0mm   1.015625mm
# ST000002_t2_flair_cor_EC_Post_Ablation_20200610...   1.015625mm   1.015625mm
# ST000002_t2_flair_cor_EC_20200610090639_17           1.015625mm   1.015625mm
# ST000002_t2_flair_tra_EC_20200610090639_16           1.015625mm   1.015625mm
# ST000002_t1_fl3d_sag_Fiber_20200610090639_101       0.5371901mm  0.5371901mm
#
#                                                         z size
# file_name
# ST000002_t1_fl3d_sag_Fiber_20200610090639_7         1.015625mm
# ST000002_T1_SE_SAG_20200610090639_10                     3.0mm
# ST000002_T1_SE_AXIAL_20200610090639_11                   3.0mm
# ST000002_t1_fl3d_sag_Fiber_20200610090639_102            1.0mm
# ST000002_t1_fl3d_sag_Pre_Ablation_20200610090639_4  1.015625mm
# ST000002_t2_flair_cor_EC_Post_Ablation_20200610...       2.0mm
# ST000002_t2_flair_cor_EC_20200610090639_17               2.0mm
# ST000002_t2_flair_tra_EC_20200610090639_16               2.0mm
# ST000002_t1_fl3d_sag_Fiber_20200610090639_101            1.0mm
#
# [9 rows x 24 columns]
